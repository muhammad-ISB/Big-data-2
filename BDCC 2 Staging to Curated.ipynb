# %% [markdown]
# # Staging Zone
#
# read data from staging tables

# %%
# Import necessary libraries
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, DoubleType, StringType, LongType, DateType, IntegerType
import pyspark.sql.functions as F

spark.conf.set("spark.sql.legacy.timeParserPolicy","LEGACY")

# %%
# %sql

-- setup default database to staging_assignment

USE staging_assignment;
SHOW Tables;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>staging_assignment</td><td>customers</td><td>false</td></tr><tr><td>staging_assignment</td><td>orders</td><td>false</td></tr></tbody></table></div>

# %% [markdown]
# # Curated Zone

# %%
# %sql 

-- setup curated database

DROP DATABASE IF EXISTS curated_assignment CASCADE;

CREATE DATABASE curated_assignment;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ## Read Staging Tables

# %%
# Read staging tables to spark dataframe

customers_df = spark.read.table("staging_assignment.customers")
customers_df.cache()
orders_df = spark.read.table("staging_assignment.orders")
orders_df.cache()
# Out:
# Out[8]: DataFrame[Order_Id: int, Order_Date: date, Status: string, Item_Id: int, Qty_Ordered: double, Price: double, Value: double, Discount_Amount: double, Total: double, Category: string, Payment_Method: string, Cust_Id: int, Year: int, Month: string]

# %%
display(customers_df.head(3))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>City</th><th>County</th><th>Customer_Since</th><th>E_Mail</th><th>Gender</th><th>Place_Name</th><th>Region</th><th>State</th><th>Zip</th><th>Age</th><th>Cust_Id</th><th>Full_Name</th></tr></thead><tbody><tr><td>Eagletown</td><td>McCurtain</td><td>2016-10-12</td><td>michelle.stabler@yahoo.com</td><td>F</td><td>Eagletown</td><td>South</td><td>OK</td><td>74734</td><td>34</td><td>87387</td><td>Stabler, Michelle</td></tr><tr><td>Belmont</td><td>Sabine</td><td>2016-05-17</td><td>peter.perreira@ntlworld.com</td><td>M</td><td>Belmont</td><td>South</td><td>LA</td><td>71406</td><td>62</td><td>87393</td><td>Perreira, Peter</td></tr><tr><td>Nelsonia</td><td>Accomack</td><td>2016-10-29</td><td>miss.dale@ibm.com</td><td>F</td><td>Nelsonia</td><td>South</td><td>VA</td><td>23414</td><td>69</td><td>87404</td><td>Dale, Miss</td></tr></tbody></table></div>

# %%
display(orders_df.head(3))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Order_Id</th><th>Order_Date</th><th>Status</th><th>Item_Id</th><th>Qty_Ordered</th><th>Price</th><th>Value</th><th>Discount_Amount</th><th>Total</th><th>Category</th><th>Payment_Method</th><th>Cust_Id</th><th>Year</th><th>Month</th></tr></thead><tbody><tr><td>100496528</td><td>2021-04-29</td><td>canceled</td><td>804885</td><td>3.0</td><td>50.0</td><td>100.0</td><td>0.0</td><td>100.0</td><td>Others</td><td>Payaxis</td><td>57890</td><td>2021</td><td>Apr-2021</td></tr><tr><td>100464507</td><td>2021-03-29</td><td>canceled</td><td>762085</td><td>3.0</td><td>600.0</td><td>1200.0</td><td>0.0</td><td>1200.0</td><td>Others</td><td>Payaxis</td><td>91123</td><td>2021</td><td>Mar-2021</td></tr><tr><td>100464508</td><td>2021-03-29</td><td>canceled</td><td>762086</td><td>2.0</td><td>400.0</td><td>400.0</td><td>0.0</td><td>400.0</td><td>Others</td><td>Payaxis</td><td>91123</td><td>2021</td><td>Mar-2021</td></tr></tbody></table></div>

# %% [markdown]
# ## Define Joint Dataframe

# %%
#create a joint table with order and cumstomer data and define new segment column

order_customer_df = orders_df.join(customers_df, on = ["Cust_Id"], how = 'left' ) \
                            .withColumn("Customer_Segment", F.when(F.col("Age")<=20,"young")
                                        .when(((F.col("Age")>20) & (F.col("Age")<=35)),"adults")
                                        .when(((F.col("Age")>35) & (F.col("Age")<=55)),"middle-ages")
                                        .when((F.col("Age")>55),"old"))

# %%
display(order_customer_df.head(30))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>
td></tr><tr><td>100481110</td><td>canceled</td><td>1</td></tr><tr><td>100481189</td><td>canceled</td><td>1</td></tr><tr><td>100482954</td><td>received</td><td>1</td></tr><tr><td>100499667</td><td>canceled</td><td>3</td></tr><tr><td>100484546</td><td>canceled</td><td>1</td></tr><tr><td>100494082</td><td>canceled</td><td>1</td></tr><tr><td>100493578</td><td>received</td><td>1</td></tr><tr><td>100495654</td><td>canceled</td><td>1</td></tr><tr><td>100496763</td><td>canceled</td><td>1</td></tr><tr><td>100496326</td><td>canceled</td><td>1</td></tr><tr><td>100493048</td><td>received</td><td>1</td></tr><tr><td>100505620</td><td>canceled</td><td>1</td></tr><tr><td>100492774</td><td>canceled</td><td>1</td></tr><tr><td>100505183</td><td>received</td><td>1</td></tr><tr><td>100492877</td><td>canceled</td><td>1</td></tr><tr><td>100496052</td><td>received</td><td>1</td></tr><tr><td>100492968</td><td>canceled</td><td>1</td></tr><tr><td>100493202</td><td>canceled</td><td>1</td></tr><tr><td>100494661</td><td>received</td><td>1</td></tr><tr><td>100493361</td><td>received</td><td>1</td></tr><tr><td>100493511</td><td>canceled</td><td>1</td></tr><tr><td>100494456</td><td>canceled</td><td>1</td></tr><tr><td>100497555</td><td>canceled</td><td>1</td></tr><tr><td>100496542</td><td>canceled</td><td>1</td></tr><tr><td>100498999</td><td>canceled</td><td>1</td></tr><tr><td>100495347</td><td>canceled</td><td>1</td></tr><tr><td>100495837</td><td>canceled</td><td>1</td></tr><tr><td>100495924</td><td>received</td><td>1</td></tr><tr><td>100496008</td><td>received</td><td>1</td></tr><tr><td>100496286</td><td>received</td><td>1</td></tr><tr><td>100500475</td><td>received</td><td>1</td></tr><tr><td>100501584</td><td>canceled</td><td>1</td></tr><tr><td>100498534</td><td>canceled</td><td>1</td></tr><tr><td>100502604</td><td>canceled</td><td>1</td></tr><tr><td>100499921</td><td>received</td><td>1</td></tr><tr><td>100500716</td><td>canceled</td><td>1</td></tr><tr><td>100503865</td><td>received</td><td>1</td></tr><tr><td>100508093</td><td>canceled</td><td>1</td></tr><tr><td>100500942</td><td>canceled</td><td>1</td></tr><tr><td>100507870</td><td>received</td><td>1</td></tr><tr><td>100501962</td><td>cancele ...

# %%
display(order_customer_df.where(F.col("Order_Id")==100555558))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Cust_Id</th><th>Order_Id</th><th>Order_Date</th><th>Status</th><th>Item_Id</th><th>Qty_Ordered</th><th>Price</th><th>Value</th><th>Discount_Amount</th><th>Total</th><th>Category</th><th>Payment_Method</th><th>Year</th><th>Month</th><th>City</th><th>County</th><th>Customer_Since</th><th>E_Mail</th><th>Gender</th><th>Place_Name</th><th>Region</th><th>State</th><th>Zip</th><th>Age</th><th>Full_Name</th><th>Customer_Segment</th></tr></thead><tbody><tr><td>110568</td><td>100555558</td><td>2021-09-08</td><td>canceled</td><td>893733</td><td>2.0</td><td>29.9</td><td>29.9</td><td>0.0</td><td>29.9</td><td>Mobiles & Tablets</td><td>bankalfalah</td><td>2021</td><td>Sep-2021</td><td>East Greenbush</td><td>Rensselaer</td><td>2016-08-11</td><td>gregory.ludlow@aol.com</td><td>M</td><td>East Greenbush</td><td>Northeast</td><td>NY
# %%
order_customer_df.columns
# Out:
# Out[15]: ['Cust_Id',
#  'Order_Id',
#  'Order_Date',
#  'Status',
#  'Item_Id',
#  'Qty_Ordered',
#  'Price',
#  'Value',
#  'Discount_Amount',
#  'Total',
#  'Category',
#  'Payment_Method',
#  'Year',
#  'Month',
#  'City',
#  'County',
#  'Customer_Since',
#  'E_Mail',
#  'Gender',
#  'Place_Name',
#  'Region',
#  'State',
#  'Zip',
#  'Age',
#  'Full_Name',
#  'Customer_Segment']

# %% [markdown]
# ## Revenue Pipeline

# %%
# Define list of columns to be used for revenue aggregations

revenue_columns =  ['Status',
                    'Category',
                    'Payment_Method',
                    'Year',
                    'Month',
                    'City',
                    'County',
                    'Gender',
                    'Region',
                    'State',
                    'Customer_Segment']

# %%
# Create revenue dataframe

revenue_agg_df = order_customer_df.groupby(revenue_columns).agg(F.sum("Total").alias("Revenue"))

# %%
display(revenue_agg_df.head(20))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Status</th><th>Category</th><th>Payment_Method</th><th>Year</th><th>Month</th><th>City</th><th>County</th><th>Gender</th><th>Region</th><th>State</th><th>Customer_Segment</th><th>Revenue</th></tr></thead><tbody><tr><td>canceled</td><td>Others</td><td>Easypay</td><td>2021</td><td>Apr-2021</td><td>Gaines</td><td>Genesee</td><td>F</td><td>Midwest</td><td>MI</td><td>old</td><td>800.0</td></tr><tr><td>complete</td><td>Others</td><td>Easypay</td><td>2021</td><td>Apr-2021</td><td>Atlantic</td><td>Carteret</td><td>M</td><td>South</td><td>NC</td><td>middle-ages</td><td>360.0</td></tr><tr><td>canceled</td><td>Others</td><td>Payaxis</td><td>2021</td><td>Apr-2021</td><td>Baltimore</td><td>Baltimore (city)</td><td>F</td><td>South</td><td>MD</td><td>middle-ages</td><td>0.0</td></tr><tr><td>canceled</td><td>Others</td><td>jazzwallet</td><td>2021</td><td>Apr-2021</td><td>Orange</td><td>Orange</td><td>F</td><td>West</td><td>CA</td><td>middle-ages</td><td>100.0</td></tr><tr><td>canceled</td><td>Others</td><td>Payaxis</td><td>2021</td><td>Apr-2021</td><td>York New Salem</td><td>York</td><td>F</td><td>Northeast</td><td>PA</td><td>old</td><td>600.0</td></tr><tr><td>received</td><td>Others</td><td>Payaxis</td><td>2021</td><td>Apr-2021</td><td>Sailor Springs</td><td>Clay</td><td>M</td><td>Midwest</td><td>IL</td><td>adults</td><td>5200.0</td></tr><tr><td>canceled</td><td>Others</td><td>Easypay</td><td>2021</td><td>Apr-2021</td><td>West Willow</td><td>Lancaster</td><td>M</td><td>Northeast</td><td>PA</td><td>middle-ages</td><td>360.0</td></tr><tr><td>canceled</td><td>Others</td><td>Easypay</td><td>2021</td><td>Apr-2021</td><td>Mamaroneck</td><td>Westchester</td><td>M</td><td>Northeast</td><td>NY</td><td>old</td><td>4000.0</td></tr><tr><td>canceled</td><td>Others</td><td>Payaxis</td><td>2021</td><td>Apr-2021</td><td>Rochester</td><td>Monroe</td><td>M</td><td>Northeast</td><td>NY</td><td>adults</td><td>0.0</td></tr><tr><td>canceled</td><td>Others</td><td>Payaxis</td><td>2021</td><td>Apr-2021</td><td>Lyon</td><td>Coahoma</td><td>M</td><td>South</td><td>MS</td><td>adults</td><td>400.0</td></tr><tr><td>canceled</td><td>Others</td><td>Payaxis</td><td>2021</td><td>Apr-2021</td><td>Atlanta</td><td>Fulton</td><td>M</td><td>South</td><td>GA</td><td>adults</td><td>14400.0</td></tr><tr><td>canceled</td><td>Others</td><td>Payaxis</td><td>2021</td><td>Apr-2021</td><td>Boynton Beach</td><td>Palm Beach</td><td>F</td><td>South</td><td>FL</td><td>middle-ages</td><td>0.0</td></tr><tr><td>received</td><td>Others</td><td>Easypay</td><td>2021</td><td>Apr-2021</td><td>Bee</td><td>Seward</td><td>M</td><td>Midwest</td><td>NE</td><td>middle-ages</td><td>1200.0</td></tr><tr><td>canceled</td><td>Others</td><td>Easypay</td><td>2021</td><td>Apr-2021</td><td>Erie</td><td>Erie</td><td>F</td><td>Northeast</td><td>PA</td><td>old</td><td>4800.0</td></tr><tr><td>received</td><td>Others</td><td>easypay_voucher</td><td>2021</td><td>Apr-2021</td><td>Inverness</td><td>Citrus</td><td>F</td><td>South</td><td>FL</td><td>old</td><td>800.0</td></tr><tr><td>canceled</td><td>Others</td><td>Payaxis</td><td>2021</td><td>Apr-2021</td><td>Tulsa</td><td>Tulsa</td><td>M</td><td>South</td><td>OK</td><td>old</td><td>1200.0</td></tr><tr><td>received</td><td>Others</td><td>bankalfalah</td><td>2021</td><td>Apr-2021</td><td>Raleigh</td><td>Wake</td><td>F</td><td>South</td><td>NC</td><td>middle-ages</td><td>200.0</td></tr><tr><td>canceled</td><td>Others</td><td>bankalfalah</td><td>2021</td><td>Apr-2021</td><td>Houston</td><td>Harris</td><td>F</td><td>South</td><td>TX</td><td>adults</td><td>250.0</td></tr><tr><td>received</td><td>Others</td><td>easypay_voucher</td><td>2021</td><td>Apr-2021</td><td>Ogunquit</td><td>York</td><td>F</td><td>Northeast</td><td>ME</td><td>middle-ages</td><td>200.0</td></tr><tr><td>canceled</td><td>Others</td><td>Easypay</td><td>2021</td><td>Apr-2021</td><td>New Haven</ ...

# %%
# Save revenue data to curated database

revenue_agg_df.write.format("delta").mode("overwrite").option("overwriteSchema", "true").partitionBy("Category").saveAsTable("curated_assignment.revenue_agg")

# %%
# %sql

USE curated_assignment;
SHOW TABLES;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>curated_assignment</td><td>customer_agg</td><td>false</td></tr><tr><td>curated_assignment</td><td>revenue_agg</td><td>false</td></tr></tbody></table></div>

# %% [markdown]
# ## Customer Pipeline

# %%
# Define list of columns to be used for customer aggregations

customer_columns =  ['Cust_Id',
                    'Full_Name',
                    'Status',
                    'Category',
                    'Payment_Method',
                    'Year',
                    'Month',
                    'City',
                    'County',
                    'Gender',
                    'Region',
                    'State',
                    'Customer_Segment']

# %%
# Create customer agg dataframe

customer_agg_df = order_customer_df.groupby(customer_columns).agg(F.sum("Total").alias("Revenue"))

# %%
# Save customer agg data to curated database

customer_agg_df.write.format("delta").mode("overwrite").option("overwriteSchema", "true").partitionBy("Category").saveAsTable("curated_assignment.customer_agg")
